# %% [markdown]
# #Modelling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, GridSearchCV,  learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_curve, auc
from xgboost import plot_importance
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Airline_Final.csv')
df.head()
# Out:
#    DEP_DELAY  tavg  prcp  wspd  OP_CARRIER_AS  OP_CARRIER_B6  OP_CARRIER_DL  \
# 0          0  18.3   0.0  12.6          False          False          False
# 1          0  18.3   0.0  12.6          False          False          False
# 2          1  18.3   0.0  12.6          False          False          False
# 3          0  18.3   0.0  12.6          False          False          False
# 4          0  18.3   0.0  12.6          False          False          False
#
#    OP_CARRIER_EV  OP_CARRIER_F9  OP_CARRIER_HA  OP_CARRIER_MQ  OP_CARRIER_NK  \
# 0          False          False          False          False           True
# 1          False          False          False          False           True
# 2          False          False          False          False           True
# 3          False          False          False          False           True
# 4          False          False          False          False           True
#
#    OP_CARRIER_OO  OP_CARRIER_UA  OP_CARRIER_US  OP_CARRIER_VX  OP_CARRIER_WN  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    DayOfWeek_Monday  DayOfWeek_Saturday  DayOfWeek_Sunday  DayOfWeek_Thursday  \
# 0             False               False             False                True
# 1             False               False             False                True
# 2             False               False             False                True
# 3             False               False             False                True
# 4             False               False             False                True
#
#    DayOfWeek_Tuesday  DayOfWeek_Wednesday  HOUR_1  HOUR_2  HOUR_3  HOUR_4  \
# 0              False                False   False   False   False   False
# 1              False                False   False   False   False   False
# 2              False                False   False   False   False   False
# 3              False                False   False   False   False   False
# 4              False                False   False   False   False   False
#
#    HOUR_5  HOUR_6  HOUR_7  HOUR_8  HOUR_9  HOUR_10  HOUR_11  HOUR_12  HOUR_13  \
# 0   False   False   False   False   False    False    False    False    False
# 1   False   False   False   False   False     True    False    False    False
# 2   False   False   False    True   False    False    False    False    False
# 3   False   False   False   False   False    False    False    False    False
# 4   False   False   False   False   False    False    False    False    False
#
#    HOUR_14  HOUR_15  HOUR_16  HOUR_17  HOUR_18  HOUR_19  HOUR_20  HOUR_21  \
# 0    False    False    False    False    False    False    False     True
# 1    False    False    False    False    False    False    False    False
# 2    False    False    False    False    False    False    False    False
# 3    False    False    False    False     True    False    False    False
# 4    False    False    False    False    False    False     True    False
#
#    HOUR_22  HOUR_23
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False
# 4    False    False

# %%
df.isna().sum()
# Out:
# DEP_DELAY              0
# tavg                   0
# prcp                   0
# wspd                   0
# OP_CARRIER_AS          0
# OP_CARRIER_B6          0
# OP_CARRIER_DL          0
# OP_CARRIER_EV          0
# OP_CARRIER_F9          0
# OP_CARRIER_HA          0
# OP_CARRIER_MQ          0
# OP_CARRIER_NK          0
# OP_CARRIER_OO          0
# OP_CARRIER_UA          0
# OP_CARRIER_US          0
# OP_CARRIER_VX          0
# OP_CARRIER_WN          0
# DayOfWeek_Monday       0
# DayOfWeek_Saturday     0
# DayOfWeek_Sunday       0
# DayOfWeek_Thursday     0
# DayOfWeek_Tuesday      0
# DayOfWeek_Wednesday    0
# HOUR_1                 0
# HOUR_2                 0
# HOUR_3                 0
# HOUR_4                 0
# HOUR_5                 0
# HOUR_6                 0
# HOUR_7                 0
# HOUR_8                 0
# HOUR_9                 0
# HOUR_10                0
# HOUR_11                0
# HOUR_12                0
# HOUR_13                0
# HOUR_14                0
# HOUR_15                0
# HOUR_16                0
# HOUR_17                0
# HOUR_18                0
# HOUR_19                0
# HOUR_20                0
# HOUR_21                0
# HOUR_22                0
# HOUR_23                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667514 entries, 0 to 5667513
# Data columns (total 46 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   DEP_DELAY            int64
#  1   tavg                 float64
#  2   prcp                 float64
#  3   wspd                 float64
#  4   OP_CARRIER_AS        bool
#  5   OP_CARRIER_B6        bool
#  6   OP_CARRIER_DL        bool
#  7   OP_CARRIER_EV        bool
#  8   OP_CARRIER_F9        bool
#  9   OP_CARRIER_HA        bool
#  10  OP_CARRIER_MQ        bool
#  11  OP_CARRIER_NK        bool
#  12  OP_CARRIER_OO        bool
#  13  OP_CARRIER_UA        bool
#  14  OP_CARRIER_US        bool
#  15  OP_CARRIER_VX        bool
#  16  OP_CARRIER_WN        bool
#  17  DayOfWeek_Monday     bool
#  18  DayOfWeek_Saturday   bool
#  19  DayOfWeek_Sunday     bool
#  20  DayOfWeek_Thursday   bool
#  21  DayOfWeek_Tuesday    bool
#  22  DayOfWeek_Wednesday  bool
#  23  HOUR_1               bool
#  24  HOUR_2               bool
#  25  HOUR_3               bool
#  26  HOUR_4               bool
#  27  HOUR_5               bool
#  28  HOUR_6               bool
#  29  HOUR_7               bool
#  30  HOUR_8               bool
#  31  HOUR_9               bool
#  32  HOUR_10              bool
#  33  HOUR_11              bool
#  34  HOUR_12              bool
#  35  HOUR_13              bool
#  36  HOUR_14              bool
#  37  HOUR_15              bool
#  38  HOUR_16              bool
#  39  HOUR_17              bool
#  40  HOUR_18              bool
#  41  HOUR_19              bool
#  42  HOUR_20              bool
#  43  HOUR_21              bool
#  44  HOUR_22              bool
#  45  HOUR_23              bool
# dtypes: bool(42), float64(3), int64(1)
# memory usage: 400.0 MB

# %%
for column in df.columns:
    print("Column:", column)
    print("Unique values:", df[column].unique())
# Out:
# Column: DEP_DELAY
# Unique values: [0 1]
# Column: tavg
# Unique values: [ 18.3        -1.7        22.8         6.3         0.7        -3.3
#   23.4        -6.7        26.4         2.7         0.9         8.4
#   -7.9        21.2        -0.9        -7.7         4.6         8.8
#    5.6        17.3        -1.5        -1.1        -5.8        -9.2
#   10.2         4.4         9.7         6.8        -7.4        -6.8
#    3.1        -9.9         2.8       -10.2         6.4         3.4
#    0.1         5.4        -4.9         7.5        -2.7        -8.3
#    8.3        14.1550502  -1.3       -13.9        -8.9        23.8
#    4.7        -9.1        -4.1         4.2         8.9         5.9
#   -4.7        -6.3         1.9        -5.4       -12.2        -2.6
#   -5.9        -2.2        -3.2        -5.5       -15.6         1.6
#   -3.1         3.6         3.3         6.5        -4.4        -4.8
#   -7.2       -11.          5.2        -7.6       -10.5       -19.3
#    0.5        -2.9         8.1       -15.9       -12.        -11.7
#  -10.8       -19.8        -8.4        -6.4         2.4       -14.
#   20.6        22.9        19.4        19.3        21.3        -6.9
#  -10.9         1.7        -3.9        -3.4         1.8        10.7
#    2.3        -5.2        -4.3       -13.        -17.4        -6.
#   -3.         -7.3         0.3       -14.4       -24.7       -18.5
#  7.87000000e+01 2.20200000e+02 5.24000000e+01 9.66000000e+01
#  1.24500000e+02 1.22200000e+02 1.49900000e+02 1.00100000e+02
#  1.72000000e+01 2.27000000e+01 7.34000000e+01 3.17200000e+02
#  1.66400000e+02 1.30600000e+02 1.34600000e+02 2.52000000e+01
#  1.16300000e+02 8.33000000e+01 2.56000000e+01 8.84000000e+01
#  9.25000000e+01 4.46000000e+01 9.96000000e+01 8.56000000e+01
#  3.42000000e+01 8.18000000e+01 7.75000000e+01 1.09000000e+02
#  1.19100000e+02 1.74000000e+01 8.20000000e+00 8.76000000e+01
#  1.15600000e+02 6.53000000e+01 2.19000000e+01 8.43000000e+01
#  7.46000000e+01 6.70000000e+00 7.00000000e+00 2.33000000e+01
#  2.30000000e+01 1.02400000e+02 1.13300000e+02 9.98000000e+01
#  1.11800000e+02 1.35600000e+02 1.05200000e+02 1.53200000e+02
#  5.06000000e+01 1.84000000e+01 1.48000000e+01 3.67000000e+01
#  8.31000000e+01 1.37300000e+02 1.43000000e+02]
# Column: wspd
# Unique values: [12.6        20.2         8.6        14.         10.1        23.
#   8.3        23.4        17.6        10.4        25.2        16.9
#  29.5         8.          3.2         5.8         1.8         7.2
#   9.4        16.6        13.         13.7         6.1         4.3
#   3.6         2.5        19.1        17.3         4.7         2.2
#  11.2         5.1         7.9        19.4         6.4        12.33534999
#   7.6        32.         34.9        13.2         6.7         5.3
#   6.8         1.1        18.7        16.2         6.9        26.2
#   9.9         4.         13.3         6.5         9.6        15.7
#  28.8        16.          3.5        30.2         3.7        29.2
#  30.4         2.9         7.7        27.7        14.9        10.8
#  13.5        11.9         4.5        20.5        15.4        12.8
#  12.2         3.8        20.4        22.9         8.9         5.4
#  16.8         3.3        26.6         2.1        10.6        39.6
#  15.5        27.          1.3        26.3        19.5        25.9
#  20.6        22.1        25.5        14.8         5.         11.4
#  21.6        12.5        15.1        12.3        14.5         8.2
#   5.7        18.         15.9        13.8        11.5        24.
#   8.8         6.3        24.7         5.9         0.4         7.5
#   5.5        24.2        27.4        24.1        18.4        22.5
#  31.         36.1        22.7        15.2         2.6        22.
#   2.8         9.7         0.7        14.4         9.5        12.9
#   8.4        15.8         9.8        19.8         9.          9.2
#  29.9        21.9         6.6        21.2        12.7         7.
#  12.         11.8         7.8         7.4         5.2         6.2
#  11.7        11.3        10.3        20.          6.          4.6
#  10.2        10.5         4.1        11.1        17.          9.3
#   5.6        24.4         8.5        36.4         4.4         1.4
#  16.4         3.4        24.5        23.8        14.2         1.5
#   2.3         4.2         4.9        11.6        28.6        40.7
#  10.7        10.         38.9         8.7         3.1        33.
#  15.6        13.6        19.6         2.         20.9        11.
#  10.9        16.1        22.3        25.6        18.3         3.9
#  13.4         1.9        24.8        27.3        32.4        28.1
#  17.4         0.9         0.         31.3        28.4        17.1
#  17.5        22.4         8.1        17.2        28.9        17.7
#  23.9        25.         18.5        33.1        21.3        18.2
#  29.7        35.         23.5        35.6         4.8         1.6
#  13.9        18.1        26.9        34.         20.3        21.4
#  45.8        31.7        34.6        33.5        21.5        30.6
#  13.1         7.1        28.3         9.1        18.9        25.8
#  23.3         1.         16.5        20.7        32.1         1.7
#  18.6        27.8        27.1        28.5        22.6         3.
#  19.7        14.6        26.5        15.         19.9        29.
#   2.4        14.7        26.         30.3        20.1        23.2
#  32.8        35.3        36.7        17.9        14.1        40.
#  51.1        19.         30.9        44.2        24.6        21.
#  37.8        16.3        27.9         2.7        25.1        23.1
#  28.7        12.1        28.2        23.7         7.3        15.3
#  22.2         1.2        17.8        19.3        19.2        25.3
#  12.4         0.6        21.1        14.3        22.8        21.8
#  36.         38.5        16.7        25.7         0.5        37.9
#  34.2        42.1        43.9        20.8        26.8        29.4
#  18.8        33.2        37.4        24.9        21.7        42.
#  33.8         0.2        27.6        23.6        34.1        26.4
#  39.7        39.5        26.1        33.3        30.         24.3
#  38.2        32.6        41.4        37.1        37.5        32.5
#  36.2        33.7        40.6        41.1        25.4        38.3
#  28.         42.8        33.4        39.2        36.3        34.4
#  35.4        39.1        29.1        44.4        41.8        34.7
#  31.2        32.9        31.5        31.6        35.8        44.6
#  39.9        32.2        30.7        32.3        29.6        44.3
#  37.6        31.1        38.1        27.5        35.2        35.1
#  31.8        33.9        29.3        30.8        36.5        30.1
#  43.2        34.3        29.8        32.7        45.         49.2
#  43.7        31.9        45.6        53.6        26.7        40.2
#  34.8        38.8        40.1        35.7        35.5        36.6
#  46.8        47.2        45.4        39.         48.2        36.8
#  27.2        40.8        35.9        34.5         0.8        50.
#  39.4        30.5        43.6        43.         40.4        51.7
#  40.3        41.6        41.2        33.6        41.9        59.
#  48.3        42.5        37.2        45.7        43.4        50.4
#  44.1        48.6        46.4        38.         39.8        44.
#  37.3        49.7        61.         38.6        38.7        46.1
#  37.         43.3       ]
# Column: OP_CARRIER_AS
# Unique values: [False  True]
# Column: OP_CARRIER_B6
# Unique values: [False  True]
# Column: OP_CARRIER_DL
# Unique values: [False  True]
# Column: OP_CARRIER_EV
# Unique values: [False  True]
# Column: OP_CARRIER_F9
# Unique values: [False  True]
# Column: OP_CARRIER_HA
# Unique values: [False  True]
# Column: OP_CARRIER_MQ
# Unique values: [False  True]
# Column: OP_CARRIER_NK
# Unique values: [ True False]
# Column: OP_CARRIER_OO
# Unique values: [False  True]
# Column: OP_CARRIER_UA
# Unique values: [False  True]
# Column: OP_CARRIER_US
# Unique values: [False  True]
# Column: OP_CARRIER_VX
# Unique values: [False  True]
# Column: OP_CARRIER_WN
# Unique values: [False  True]
# Column: DayOfWeek_Monday
# Unique values: [False  True]
# Column: DayOfWeek_Saturday
# Unique values: [False  True]
# Column: DayOfWeek_Sunday
# Unique values: [False  True]
# Column: DayOfWeek_Thursday
# Unique values: [ True False]
# Column: DayOfWeek_Tuesday
# Unique values: [False  True]
# Column: DayOfWeek_Wednesday
# Unique values: [False  True]
# Column: HOUR_1
# Unique values: [False  True]
# Column: HOUR_2
# Unique values: [False  True]
# Column: HOUR_3
# Unique values: [False  True]
# Column: HOUR_4
# Unique values: [False  True]
# Column: HOUR_5
# Unique values: [False  True]
# Column: HOUR_6
# Unique values: [False  True]
# Column: HOUR_7
# Unique values: [False  True]
# Column: HOUR_8
# Unique values: [False  True]
# Column: HOUR_9
# Unique values: [False  True]
# Column: HOUR_10
# Unique values: [False  True]
# Column: HOUR_11
# Unique values: [False  True]
# Column: HOUR_12
# Unique values: [False  True]
# Column: HOUR_13
# Unique values: [False  True]
# Column: HOUR_14
# Unique values: [False  True]
# Column: HOUR_15
# Unique values: [False  True]
# Column: HOUR_16
# Unique values: [False  True]
# Column: HOUR_17
# Unique values: [False  True]
# Column: HOUR_18
# Unique values: [False  True]
# Column: HOUR_19
# Unique values: [False  True]
# Column: HOUR_20
# Unique values: [False  True]
# Column: HOUR_21
# Unique values: [ True False]
# Column: HOUR_22
# Unique values: [False  True]
# Column: HOUR_23
# Unique values: [False  True]

# %%
# Extracting numerical features
numerical_features = df.select_dtypes(include=['float64'])

# Standardizing numerical features
scaler = StandardScaler()
scaled_numerical_features = scaler.fit_transform(numerical_features)
df.drop(columns=numerical_features.columns, inplace=True)
new_df = pd.DataFrame(data=scaled_numerical_features, columns=numerical_features.columns)
data2 = pd.concat([df, new_df], axis=1)

# %%
bool_columns = data2.select_dtypes(include=bool).columns
data2[bool_columns] = data2[bool_columns].astype(int) # converting boolean columns to integers (0 and 1)

# %%
delay_0 = data2[data2['DEP_DELAY'] == 0].sample(n=100000, random_state=821)
delay_1 = data2[data2['DEP_DELAY'] == 1].sample(n=100000, random_state=821)

# Concatenating the sampled dataframes
data = pd.concat([delay_0, delay_1], ignore_index=True)

# %%
data.isna().sum()
# Out:
# DEP_DELAY              0
# OP_CARRIER_AS          0
# OP_CARRIER_B6          0
# OP_CARRIER_DL          0
# OP_CARRIER_EV          0
# OP_CARRIER_F9          0
# OP_CARRIER_HA          0
# OP_CARRIER_MQ          0
# OP_CARRIER_NK          0
# OP_CARRIER_OO          0
# OP_CARRIER_UA          0
# OP_CARRIER_US          0
# OP_CARRIER_VX          0
# OP_CARRIER_WN          0
# DayOfWeek_Monday       0
# DayOfWeek_Saturday     0
# DayOfWeek_Sunday       0
# DayOfWeek_Thursday     0
# DayOfWeek_Tuesday      0
# DayOfWeek_Wednesday    0
# HOUR_1                 0
# HOUR_2                 0
# HOUR_3                 0
# HOUR_4                 0
# HOUR_5                 0
# HOUR_6                 0
# HOUR_7                 0
# HOUR_8                 0
# HOUR_9                 0
# HOUR_10                0
# HOUR_11                0
# HOUR_12                0
# HOUR_13                0
# HOUR_14                0
# HOUR_15                0
# HOUR_16                0
# HOUR_17                0
# HOUR_18                0
# HOUR_19                0
# HOUR_20                0
# HOUR_21                0
# HOUR_22                0
# HOUR_23                0
# tavg                   0
# prcp                   0
# wspd                   0
# dtype: int64

# %%
X = data.drop(columns=['DEP_DELAY'])
y = data['DEP_DELAY']

# smote = SMOTE(random_state=821)
# X, y= smote.fit_resample(X, y)
# data2 = pd.DataFrame(X, columns=X.columns)
# data2['DEP_DELAY'] = y

# print("After SMOTE:")
# print(data2['DEP_DELAY'].value_counts())

# %%
# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=821)


print("Train set - X:", X_train.shape, "y:", y_train.shape)
print("Test set - X:", X_test.shape, "y:", y_test.shape)
# Out:
# Train set - X: (140000, 45) y: (140000,)
# Test set - X: (60000, 45) y: (60000,)

# %%
def plot_learning_curve(estimator, title, X, y, cv=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")

    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, train_sizes=train_sizes, scoring='accuracy', n_jobs=-1)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
lr_model = LogisticRegression(max_iter=1000, solver='sag')
lr_param_grid = {'C': [0.01, 0.1, 0.5, 1, 10]}
lr_grid_search = GridSearchCV(lr_model, lr_param_grid, scoring='accuracy', cv=5)
lr_grid_result = lr_grid_search.fit(X_train, y_train)

# Predictions on training and testing data
lr_y_train_pred = lr_grid_result.predict(X_train)
lr_y_test_pred = lr_grid_result.predict(X_test)

# Classification report for training and testing sets
print("Logistic Regression Metrics:")
print("Best Parameters:", lr_grid_result.best_params_)
print("Classification Report for Training:")
print(classification_report(y_train, lr_y_train_pred))
print("Classification Report for Testing:")
print(classification_report(y_test, lr_y_test_pred))

# ROC curve and AUC score
lr_probs = lr_grid_result.predict_proba(X_test)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(y_test, lr_probs)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.figure()
plt.plot(fpr_lr, tpr_lr, lw=2, label='Logistic Regression (area = %0.2f)' % roc_auc_lr)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression')
plt.legend(loc="lower right")

# Learning curve
title_lr = "Learning Curve (Logistic Regression)"
plot_learning_curve(lr_grid_result.best_estimator_, title_lr, X_train, y_train, cv=5)

plt.show()
# Out:
# Logistic Regression Metrics:
# Best Parameters: {'C': 0.01}
# Classification Report for Training:
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61     69967
#            1       0.61      0.64      0.62     70033
#
#     accuracy                           0.62    140000
#    macro avg       0.62      0.62      0.62    140000
# weighted avg       0.62      0.62      0.62    140000
#
# Classification Report for Testing:
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61     30033
#            1       0.61      0.64      0.62     29967
#
#     accuracy                           0.62     60000
#    macro avg       0.62      0.62      0.62     60000
# weighted avg       0.62      0.62      0.62     60000

# %%
# Random Forest
rf_model = RandomForestClassifier()
rf_param_grid = {'n_estimators': [100, 300, 400, 500, 700], 'max_depth': [2, 3, 5, 7, 9, 11], 'min_samples_split': [2, 3, 5, 10, 15]}
rf_grid_search = GridSearchCV(rf_model, rf_param_grid, scoring='accuracy', cv=5)
rf_grid_result = rf_grid_search.fit(X_train, y_train)

# Predictions on training and testing data
rf_y_train_pred = rf_grid_result.predict(X_train)
rf_y_test_pred = rf_grid_result.predict(X_test)

# Classification report for training and testing sets
print("Random Forest Metrics:")
print("Best Parameters:", rf_grid_result.best_params_)
print("Classification Report for Training:")
print(classification_report(y_train, rf_y_train_pred))
print("Classification Report for Testing:")
print(classification_report(y_test, rf_y_test_pred))

# ROC curve and AUC score
rf_probs = rf_grid_result.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_probs)
roc_auc_rf = auc(fpr_rf, tpr_rf)
plt.figure()
plt.plot(fpr_rf, tpr_rf, lw=2, label='Random Forest (area = %0.2f)' % roc_auc_rf)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest')
plt.legend(loc="lower right")

# Learning curve
title_rf = "Learning Curve (Random Forest)"
plot_learning_curve(rf_grid_result.best_estimator_, title_rf, X_train, y_train, cv=5)

plt.show()

# %%
# KNN model
knn_model = KNeighborsClassifier()
knn_param_grid = {'n_neighbors': [2, 3, 4, 5, 7], 'weights': ['uniform', 'distance']}
knn_grid_search = GridSearchCV(knn_model, knn_param_grid, scoring='accuracy', cv=5)
knn_grid_result = knn_grid_search.fit(X_train, y_train)

# Predictions on training and testing data
knn_y_train_pred = knn_grid_result.predict(X_train)
knn_y_test_pred = knn_grid_result.predict(X_test)

# Classification report for training and testing sets
print("KNN Metrics:")
print("Best Parameters:", knn_grid_result.best_params_)
print("Classification Report for Training:")
print(classification_report(y_train, knn_y_train_pred))
print("Classification Report for Testing:")
print(classification_report(y_test, knn_y_test_pred))

# ROC curve and AUC score
knn_probs = knn_grid_result.predict_proba(X_test)[:, 1]
fpr_knn, tpr_knn, _ = roc_curve(y_test, knn_probs)
roc_auc_knn = auc(fpr_knn, tpr_knn)
plt.figure()
plt.plot(fpr_knn, tpr_knn, lw=2, label='KNN (area = %0.2f)' % roc_auc_knn)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for KNN')
plt.legend(loc="lower right")

# Learning curve
title_knn = "Learning Curve (KNN)"
plot_learning_curve(knn_grid_result.best_estimator_, title_knn, X_train, y_train, cv=5)

plt.show()
# Out:
# KNN Metrics:
# Best Parameters: {'n_neighbors': 7, 'weights': 'uniform'}
# Classification Report for Training:
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70     69967
#            1       0.70      0.69      0.70     70033
#
#     accuracy                           0.70    140000
#    macro avg       0.70      0.70      0.70    140000
# weighted avg       0.70      0.70      0.70    140000
#
# Classification Report for Testing:
#               precision    recall  f1-score   support
#
#            0       0.58      0.60      0.59     30033
#            1       0.59      0.57      0.58     29967
#
#     accuracy                           0.59     60000
#    macro avg       0.59      0.59      0.58     60000
# weighted avg       0.59      0.59      0.58     60000

# %%
# XGBoost
xgb_model = XGBClassifier(enable_categorical=True)
xgb_param_grid = {'n_estimators': [50, 100, 200, 300, 500], 'learning_rate': [0.01, 0.05, 0.1, 0.5, 1], 'max_depth': [3, 5, 7, 9]}
xgb_grid_search = GridSearchCV(xgb_model, xgb_param_grid, scoring='accuracy', cv=5)
xgb_grid_result = xgb_grid_search.fit(X_train, y_train)

# Predictions on training and testing data
xgb_y_train_pred = xgb_grid_result.predict(X_train)
xgb_y_test_pred = xgb_grid_result.predict(X_test)

# Classification report for training and testing sets
print("XGBoost Metrics:")
print("Best Parameters:", xgb_grid_result.best_params_)
print("Classification Report for Training:")
print(classification_report(y_train, xgb_y_train_pred))
print("Classification Report for Testing:")
print(classification_report(y_test, xgb_y_test_pred))

# ROC curve and AUC score
xgb_probs = xgb_grid_result.predict_proba(X_test)[:, 1]
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, xgb_probs)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)
plt.figure()
plt.plot(fpr_xgb, tpr_xgb, lw=2, label='XGBoost (area = %0.2f)' % roc_auc_xgb)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for XGBoost')
plt.legend(loc="lower right")

# Learning curve
title_xgb = "Learning Curve (XGBoost)"
plot_learning_curve(xgb_grid_result.best_estimator_, title_xgb, X_train, y_train, cv=5)

plt.show()

# %%
# Plot feature importances
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plot_importance(xgb_grid_result.best_estimator_, ax=ax)
plt.show()
